# %% [markdown]
# <a href="https://colab.research.google.com/github/otitamario/sp-pa-gep/blob/main/bootstrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p notebooks src figures

# %%
# !touch src/__init__.py
# !touch src/algorithms.py
# !touch src/operators.py
# !touch src/utils.py
# !touch figures/.gitkeep

# %%
# !mkdir -p notebooks src figures
# !mv bootstrap.ipynb notebooks/exp1_baseline_sppa_wppa.ipynb
# Out:
# mv: cannot stat 'bootstrap.ipynb': No such file or directory

# %%
# !pwd
# !ls -la
# Out:
# /content
# total 28
# drwxr-xr-x 1 root root 4096 Dec 28 14:51 .
# drwxr-xr-x 1 root root 4096 Dec 28 14:48 ..
# drwxr-xr-x 4 root root 4096 Dec 11 14:34 .config
# drwxr-xr-x 2 root root 4096 Dec 28 14:51 figures
# drwxr-xr-x 2 root root 4096 Dec 28 14:51 notebooks
# drwxr-xr-x 1 root root 4096 Dec 11 14:34 sample_data
# drwxr-xr-x 2 root root 4096 Dec 28 14:51 src

# %%
# %%writefile src/__init__.py
# package marker
# Out:
# Overwriting src/__init__.py

# %%
# %%writefile src/algorithms.py
"""
Algorithms: SPPA, WPPA, (later PPA, EG)
"""
# Out:
# Overwriting src/algorithms.py

# %%
# %%writefile src/operators.py
"""
Operators / resolvents / projections
"""
# Out:
# Overwriting src/operators.py

# %%
# %%writefile src/utils.py
"""
Utilities
"""
# Out:
# Overwriting src/utils.py
